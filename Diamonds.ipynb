# %% [markdown]
# <a href="https://colab.research.google.com/github/raynajindal/Diamond_Price_Prediction/blob/main/Diamonds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Predicting the value of a diamond based on the characteristics of it.
# (carat, cut, color, depth, and clarity)

# %%
#https://www.kaggle.com/shivam2503/diamonds?select=diamonds.csv
#diamonds
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/diamonds.csv')

# %%
df
# Out:
#        Unnamed: 0  carat        cut color  ... price     x     y     z
# 0               1   0.23      Ideal     E  ...   326  3.95  3.98  2.43
# 1               2   0.21    Premium     E  ...   326  3.89  3.84  2.31
# 2               3   0.23       Good     E  ...   327  4.05  4.07  2.31
# 3               4   0.29    Premium     I  ...   334  4.20  4.23  2.63
# 4               5   0.31       Good     J  ...   335  4.34  4.35  2.75
# ...           ...    ...        ...   ...  ...   ...   ...   ...   ...
# 53935       53936   0.72      Ideal     D  ...  2757  5.75  5.76  3.50
# 53936       53937   0.72       Good     D  ...  2757  5.69  5.75  3.61
# 53937       53938   0.70  Very Good     D  ...  2757  5.66  5.68  3.56
# 53938       53939   0.86    Premium     H  ...  2757  6.15  6.12  3.74
# 53939       53940   0.75      Ideal     D  ...  2757  5.83  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
#Max carat size
df['carat'].max()
# Out:
# 5.01

# %%
#Min carat size

df['carat'].min()
# Out:
# 0.2

# %% [markdown]
# Histograms are representing the count based on each of the characteristics.

# %%
def graph_histogram(column_name, color_name): 
  import seaborn as sns

  sns.set()

  import matplotlib.pyplot as plt

  plt.figure(figsize=(8,5))

  #x value
  plt.xlabel(column_name)
  #y value
  plt.ylabel("Count") 

  #description 
  plt.title(f'{column_name} Histogram', size=16)

  plt.hist(df[column_name],color=color_name,alpha=0.5)
  plt.show()

# %%
#carat
graph_histogram('carat', 'navy')

# %%
#cut
graph_histogram('cut', 'green')

# %%
#color
graph_histogram('color', 'pink')

# %%
#clarity
graph_histogram('clarity', 'yellow')

# %%
#depth
graph_histogram('depth', 'purple')

# %% [markdown]
# Scatter plot shows the price variation based on the carat and the depth.

# %%
#carat
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
#x value
plt.xlabel('carat')
  #y value
plt.ylabel("price") 
plt.scatter(df['carat'], df['price'])
plt.show()

# %% [markdown]
# As the carat or the weight of the diamond goes higher so does the price.

# %%
#depth
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.xlabel('depth')
  #y value
plt.ylabel("price") 
plt.scatter(df['depth'], df['price'])
plt.show()

# %% [markdown]
# Depth doesn't change the price of the diamond as much.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 

sns.set()
plt.figure(figsize=(10,8)) 
sns.scatterplot(data=df, x='carat', y='price', hue='cut')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(10, 8))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="carat", y="price",
                size="depth",
                palette="ch:r=-.2,d=.3_r",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)

# %%
sns.set_theme(style="whitegrid")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(10, 8))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="cut", y="price",
                size="cut",
                palette="ch:r=-.2,d=.3_r",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(10, 8))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(10, 8))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ['Fair','Very Good','Good','Premium','Ideal']
sns.scatterplot(x="carat", y="price",
                hue="cut", 
                palette="ch:r=-.1,d=.2_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(10, 8))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ['J','I','H','G','F','E','D']
sns.scatterplot(x="carat", y="price",
                hue="color",
                palette="ch:r=-0.2,d=0.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)

# %% [markdown]
# Checking for uniqueness and replacing categorical values with numerical values.

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['cut'] = df['cut'].replace(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'],[4,3,2,1,0])

# %%
df['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
df['clarity'] = df['clarity'].replace(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],[1,2,3,4,5,6,7,8])

# %%
df['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df['color'] = df['color'].replace(['E', 'I', 'J', 'H', 'F', 'G', 'D'],[5,9,10,11,6,7,4])

# %%
# Numerical dataset
df.head()
# Out:
#    Unnamed: 0  carat  cut  color  clarity  ...  table  price     x     y     z
# 0           1   0.23    4      5        1  ...   55.0    326  3.95  3.98  2.43
# 1           2   0.21    3      5        2  ...   61.0    326  3.89  3.84  2.31
# 2           3   0.23    2      5        3  ...   65.0    327  4.05  4.07  2.31
# 3           4   0.29    3      9        4  ...   58.0    334  4.20  4.23  2.63
# 4           5   0.31    2     10        1  ...   58.0    335  4.34  4.35  2.75
#
# [5 rows x 11 columns]

# %%
#Checking for null values.
df.info() 
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  int64
#  3   color       53940 non-null  int64
#  4   clarity     53940 non-null  int64
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(5)
# memory usage: 4.5 MB
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# There aren't any null values so I didn't have to clean the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  int64
#  3   color       53940 non-null  int64
#  4   clarity     53940 non-null  int64
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(5)
# memory usage: 4.5 MB

# %%
# y variable
y = df['price']
# x variable
X = df[['carat','depth','cut','color','clarity']]

# %% [markdown]
# Model Predictions

# %%
# Linear Regression 
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X,y)
model.score(X,y)
# Out:
# 0.877549423991755

# %%
# Splitting the training and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
#total data
X.count()
# Out:
# carat      53940
# depth      53940
# cut        53940
# color      53940
# clarity    53940
# dtype: int64

# %%
#training data 
X_train.count()
# Out:
# carat      40455
# depth      40455
# cut        40455
# color      40455
# clarity    40455
# dtype: int64

# %%
#test data
X_test.count()
# Out:
# carat      13485
# depth      13485
# cut        13485
# color      13485
# clarity    13485
# dtype: int64

# %%
model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8754895215352958

# %%
y_test_prediction=model.predict(X_test)

# %%
# Dataframe for the actual price v.s. the predicted price for the test data. 
dy = pd.DataFrame()
dy['price'] = y_test
dy['predicted price * linear'] = y_test_prediction
dy.head()
# Out:
#        price  predicted price * linear
# 53192   2633               3158.845923
# 28448    671                174.919266
# 34935    376              -1073.170701
# 23596  11613               9591.756720
# 4273    3583               3561.984755

# %%
# Decision Tree Regressor 
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9654935860594184

# %%
y_predicted_price = model.predict(X_test)

# %%
dy['predicted price * decision tree'] = y_predicted_price
dy.head()
# Out:
#        price  predicted price * linear  predicted price * decision tree
# 53192   2633               3158.845923                           2282.0
# 28448    671                174.919266                            671.0
# 34935    376              -1073.170701                            394.0
# 23596  11613               9591.756720                          12030.0
# 4273    3583               3561.984755                           4404.0

# %%
#XGBRegressor
from xgboost import XGBRegressor

model = XGBRegressor()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# [17:12:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9669894762043328

# %%
y_predicted_price = model.predict(X_test)

# %%
dy['predicted price * XGBR'] = y_predicted_price
dy.head()
# Out:
#        price  ...  predicted price * XGBR
# 53192   2633  ...             2527.323242
# 28448    671  ...              880.275146
# 34935    376  ...              362.425385
# 23596  11613  ...            10965.296875
# 4273    3583  ...             3286.946045
#
# [5 rows x 4 columns]

# %%
# Random Forest regressor 
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9789947549291717

# %%
y_predicted_price = model.predict(X_test)

# %%
dy['predicted price * Random Forest'] = y_predicted_price
dy.head()
# Out:
#        price  ...  predicted price * Random Forest
# 53192   2633  ...                      2340.890278
# 28448    671  ...                       695.324167
# 34935    376  ...                       411.757500
# 23596  11613  ...                     11599.347857
# 4273    3583  ...                      3892.880000
#
# [5 rows x 5 columns]

# %% [markdown]
# Based on the score and the table linear regression has the worst predicted value as compared to the rest.

# %% [markdown]
# #Cross Validation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor, XGBRFRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
def cross_val(model, cv=10):
  neg_mean_squared_scores = cross_val_score(model, X, y, cv=cv, 
                           scoring='neg_mean_squared_error')
  rmse = (-neg_mean_squared_scores)**0.5
  return rmse.mean()

# %%
cross_val(LinearRegression())
# Out:
# 1364.770827482131

# %%
cross_val(DecisionTreeRegressor())
# Out:
# 1018.6453404073445

# %%
cross_val(RandomForestRegressor())
# Out:
# 811.4811566028108

# %%
cross_val(XGBRegressor())
# Out:
# [17:14:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
cross_val( XGBRFRegressor())
# Out:
# [17:14:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
cross_val(KNeighborsRegressor())
# Out:
# 1405.1593684354434

# %%
y.describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %% [markdown]
# #Hyperparameter Fine-Tuning

# %%
cross_val(XGBRegressor(objective='reg:squarederror', 
                       max_depth=5,
                       n_estimators=500,
                       subsample=0.5))
# Out:
# 642.316761068159

# %%
cross_val(DecisionTreeRegressor(max_depth=12))
# Out:
# 991.0391960421769

# %%
cross_val(RandomForestRegressor(max_depth=6, n_estimators=200,
                                min_samples_split=6))
# Out:
# 1165.722177079534

# %% [markdown]
# GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

xgb = XGBRegressor(objective='reg:squarederror')
params = {'max_depth':[2, 3, 5, 6, 8]}

# Instantiate GridSearchCV as grid_reg
grid = GridSearchCV(xgb, params)

# Fit grid_reg on X_train and y_train
grid.fit(X, y)

# Extract best params
best_params = grid.best_params_

# Print best params
print("Best params:", best_params)

# Compute best score
best_score = grid.best_score_

# Print best score
print("Best score: {:.5f}".format(best_score))
# Out:
# Best params: {'max_depth': 5}
# Best score: 0.49604

# %%
# View stats of target column
df['price'].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64
